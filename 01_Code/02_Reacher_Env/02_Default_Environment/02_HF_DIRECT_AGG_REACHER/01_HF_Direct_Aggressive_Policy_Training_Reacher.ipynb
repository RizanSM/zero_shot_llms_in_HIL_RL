# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/RizanSM/zero_shot_llms_in_HIL_RL/blob/main/01_Code/02_Reacher_Env/02_Default_Environment/02_HF_DIRECT_AGG_REACHER/01_HF_Direct_Aggressive_Policy_Training_Reacher.ipynb)

# %%
# !pip install gymnasium mujoco stable-baselines3 -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 32.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.2/187.2 kB 8.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 70.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 52.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 31.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 89.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.5/243.5 kB 17.5 MB/s eta 0:00:00

# %%
# Import the necessary libraries
import gymnasium as gym
import numpy as np
import pandas as pd
import pickle
import os
import matplotlib.pyplot as plt

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor
from google.colab import data_table
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# Mounted at /content/drive

# %%
# Load the dataframe back from the pickle file
trajectory_df = pd.read_pickle('/content/drive/MyDrive/05_zero_shot_llm_3/03_reacher_data/02_trajectories/0_initial_training/0_initial_trajectory_reacher_df.pkl')      # Update directory location 1

# %%
# Display the data frame
data_table.enable_dataframe_formatter()
data_table.DataTable(trajectory_df)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Check the data type of each column
print(type(trajectory_df['Episode'][0]))
print(type(trajectory_df['Timestep'][0]))
print(type(trajectory_df['State'][0]))
print(type(trajectory_df['Action'][0]))
print(type(trajectory_df['Reward'][0]))
print(type(trajectory_df['Next State'][0]))
# Out:
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.float64'>
# <class 'numpy.ndarray'>

# %%
trajectory_df.dtypes
# Out:
# Episode         int64
# Timestep        int64
# State          object
# Action         object
# Reward        float64
# Next State     object
# dtype: object

# %% [markdown]
# HUMAN FEEDBACK IMPLEMENTATION (IDEAL CASE SCENARIO)

# %%
def calculate_different_rewards(trajectory_df):
    """Calculates effort-based reward and returns updated dataframe."""
    df = trajectory_df.copy()

    df['Distance Reward'] = -df['State'].apply(lambda x: np.linalg.norm(np.array(x)[8:10], axis=0))

    df['Smoothness Reward'] = -np.abs(df['State'].apply(lambda x: np.array(x)[6:8]).apply(np.linalg.norm))

    # df['Effort Reward'] = -df['Action'].apply(lambda x: np.linalg.norm(np.array(x)**2, axis=0))
    df['Effort Reward'] = -df['Action'].apply(lambda x: np.linalg.norm(np.array(x), axis=0))
    return df

# %%
different_rewards_df = calculate_different_rewards(trajectory_df)

# %%
data_table.enable_dataframe_formatter()
data_table.DataTable(different_rewards_df)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
def compute_weighted_rewards(df):
    # Step 1: Create a copy of the dataframe
    df = df.copy()

    # Step 2: Compute min and max values for Smoothness Reward and Effort Reward
    min_smoothness = df["Smoothness Reward"].min()
    max_smoothness = df["Smoothness Reward"].max()
    print(f"Minimum Smoothness Reward: {min_smoothness}")
    print(f"Maximum Smoothness Reward: {max_smoothness}")

    min_effort = df["Effort Reward"].min()
    max_effort = df["Effort Reward"].max()
    print(f"Minimum Effort Reward: {min_effort}")
    print(f"Maximum Effort Reward: {max_effort}")

    # Step 3: Compute Smoothness Score Range and Effort Score Range
    xsmooth = 1 / abs(max_smoothness - min_smoothness)
    xeffort = 1 / abs(max_effort - min_effort)

    print(f"Smoothness Score Range: {xsmooth}")
    print(f"Effort Score Range: {xeffort}")

    # Step 4: Compute Smoothness Weight (λ) and Effort Weight (ε) using Softmax
    exp_xsmooth = np.exp(xsmooth)
    exp_xeffort = np.exp(xeffort)

    lambda_smooth = exp_xsmooth / (exp_xsmooth + exp_xeffort)
    epsilon_effort = exp_xeffort / (exp_xsmooth + exp_xeffort)

    # Adjust weights based on bias type
    # bias_type == "aggressive":
    lambda_smooth *= -2  # Reduce smoothness importance                          # bias value 1
    epsilon_effort *= 2  # Increase effort tolerance                            # bias value 2

    print(f"Smoothness Weight (λ): {lambda_smooth}")
    print(f"Effort Weight (ε): {epsilon_effort}")

    # Step 5: Compute Smoothness Weighted Reward (R1) and Effort Weighted Reward (R2)
    df["Smoothness Weighted Reward"] = -df["Distance Reward"] - lambda_smooth * df["Smoothness Reward"]
    df["Effort Weighted Reward"] = -df["Distance Reward"] - epsilon_effort * df["Effort Reward"]

    #df["Smoothness Weighted Reward"] = df["Distance Reward"] + lambda_smooth * df["Smoothness Reward"]
    #df["Effort Weighted Reward"] = df["Distance Reward"] + epsilon_effort * df["Effort Reward"]

    return df

# %%
reward_df = compute_weighted_rewards(different_rewards_df)
# Out:
# Minimum Smoothness Reward: -9.647165745920095
# Maximum Smoothness Reward: -0.000848030583177548
# Minimum Effort Reward: -0.5573621988296509
# Maximum Effort Reward: -0.0008373789023607969
# Smoothness Score Range: 0.10366650047303289
# Effort Score Range: 1.7968650529021328
# Smoothness Weight (λ): -0.31071132469306273
# Effort Weight (ε): 1.6892886753069372

# %%
data_table.enable_dataframe_formatter()
data_table.DataTable(reward_df)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Function to recalibrate the rewards
def recalibrate_rewards(df):
    # Create a copy of the dataframe
    df_copy = df.copy()

    alpha = 1
    # Create the 'Recalibrated_rewards' column
    df_copy['Recalibrated Reward'] = df_copy['Reward'] + alpha * (df_copy['Smoothness Weighted Reward'] + df_copy['Effort Weighted Reward'])

    # Get the list of recalibrated rewards
    recalibrated_rewards_list = df_copy['Recalibrated Reward'].tolist()

    return df_copy, recalibrated_rewards_list

# %%
# Apply the function to recalibrate rewards
recalibrated_df, recalibrated_rewards_list = recalibrate_rewards(reward_df)

# %%
data_table.enable_dataframe_formatter()
data_table.DataTable(recalibrated_df)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
recalibrated_df.to_pickle('/content/drive/MyDrive/05_zero_shot_llm_3/03_reacher_data/02_trajectories/1_human_feedback/2_Hf_D_Aggressive_Reacher_df_3.pkl')         # Update directory location 2

# %%
# To access the reward for a specific step:
for i, feedback in enumerate(recalibrated_rewards_list):
    human_recalibrated_reward_for_step = recalibrated_rewards_list[i]
    print(f"Recalibrated reward for step {i}: {human_recalibrated_reward_for_step}")
# Out:
# Recalibrated reward for step 0: 0.26324932877224194
# Recalibrated reward for step 1: 0.11954772471904225
# Recalibrated reward for step 2: 0.07766882367762479
# Recalibrated reward for step 3: -0.016785671805920332
# Recalibrated reward for step 4: -0.35746876853916565
# Recalibrated reward for step 5: -0.3339836320839013
# Recalibrated reward for step 6: -0.45920396019285753
# Recalibrated reward for step 7: -0.3155080687829392
# Recalibrated reward for step 8: -0.33452096408523146
# Recalibrated reward for step 9: -0.44677187300919735
# Recalibrated reward for step 10: -0.5815953950443253
# Recalibrated reward for step 11: -0.7446699424068203
# Recalibrated reward for step 12: -1.0250982540169546
# Recalibrated reward for step 13: -0.8105437774478153
# Recalibrated reward for step 14: -1.0063857113177759
# Recalibrated reward for step 15: -0.9850434001586653
# Recalibrated reward for step 16: -0.9937845112689558
# Recalibrated reward for step 17: -0.7132326555752633
# Recalibrated reward for step 18: -1.0676807479048103
# Recalibrated reward for step 19: -1.0233711813151447
# Recalibrated reward for step 20: -1.147804735838267
# Recalibrated reward for step 21: -1.1519100651624263
# Recalibrated reward for step 22: -1.1476064168130633
# Recalibrated reward for step 23: -1.0886531678996318
# Recalibrated reward for step 24: -0.9272217509169147
# Recalibrated reward for step 25: -0.9493511629191157
# Recalibrated reward for step 26: -1.151436070055878
# Recalibrated reward for step 27: -1.0339795767949793
# Recalibrated reward for step 28: -1.1681671646308345
# Recalibrated reward for step 29: -1.1760035444872758
# Recalibrated reward for step 30: -1.2140831595897825
# Recalibrated reward for step 31: -1.2774770810142357
# Recalibrated reward for step 32: -1.064765333830356
# Recalibrated reward for step 33: -1.3198865736252285
# Recalibrated reward for step 34: -1.2754774970830498
# Recalibrated reward for step 35: -1.5825785141755526
# Recalibrated reward for step 36: -1.649277132570169
# Recalibrated reward for step 37: -1.5579351323588757
# Recalibrated reward for step 38: -1.8243452974435643
# Recalibrated reward for step 39: -1.8256205540067354
# Recalibrated reward for step 40: -1.8256861752484774
# Recalibrated reward for step 41: -1.8900845342732822
# Recalibrated reward for step 42: 0.23448989311783697
# Recalibrated reward for step 43: 0.05656295273350753
# Recalibrated reward for step 44: 0.1108652082467132
# Recalibrated reward for step 45: -0.08424440215865439
# Recalibrated reward for step 46: -0.18563628090929607
# Recalibrated reward for step 47: -0.26172683391292684
# Recalibrated reward for step 48: -0.20372775086009864
# Recalibrated reward for step 49: -0.28672956271886907
# Recalibrated reward for step 50: 0.7081573472544087
# Recalibrated reward for step 51: 0.42904850164598307
# Recalibrated reward for step 52: -0.40704353839234597
# Recalibrated reward for step 53: -0.7353307240075431
# Recalibrated reward for step 54: -0.9181796176579299
# Recalibrated reward for step 55: -1.0266294015441713
# Recalibrated reward for step 56: -1.2669871557662529
# Recalibrated reward for step 57: -1.2025826331946534
# Recalibrated reward for step 58: -0.9957462309409328
# Recalibrated reward for step 59: -1.0363371327764177
# Recalibrated reward for step 60: -0.8827403096850438
# Recalibrated reward for step 61: -0.9711120053595286
# Recalibrated reward for step 62: -0.7770404797298117
# Recalibrated reward for step 63: -0.8500969598541341
# Recalibrated reward for step 64: -0.927641683662448
# Recalibrated reward for step 65: -0.7683153569216996
# Recalibrated reward for step 66: -1.011284198894051
# Recalibrated reward for step 67: -0.9687888645454235
# Recalibrated reward for step 68: -0.7822025727378911
# Recalibrated reward for step 69: -1.035158382862201
# Recalibrated reward for step 70: -1.0129622445667947
# Recalibrated reward for step 71: -0.9483866941565413
# Recalibrated reward for step 72: -0.9466652725542258
# Recalibrated reward for step 73: -0.9543286719228948
# Recalibrated reward for step 74: -0.9579772891531428
# Recalibrated reward for step 75: -0.8838070379499341
# Recalibrated reward for step 76: -0.9232576954373056
# Recalibrated reward for step 77: -0.7759520179620613
# Recalibrated reward for step 78: -0.6266355393861907
# Recalibrated reward for step 79: -0.6663282213344117
# Recalibrated reward for step 80: -0.682551488584558
# Recalibrated reward for step 81: -0.5314176799920732
# Recalibrated reward for step 82: -0.5322559375206154
# Recalibrated reward for step 83: -0.42541795280677575
# Recalibrated reward for step 84: -0.4438589873163862
# Recalibrated reward for step 85: -0.3709094622793177
# Recalibrated reward for step 86: -0.25919084887431904
# Recalibrated reward for step 87: -0.3295160059640684
# Recalibrated reward for step 88: -0.2589215646511215
# Recalibrated reward for step 89: -0.25524906123999397
# Recalibrated reward for step 90: -0.19426296396435838
# Recalibrated reward for step 91: -0.08684700839508214
# Recalibrated reward for step 92: -0.1860819735042896
# Recalibrated reward for step 93: -0.15924242968407368
# Recalibrated reward for step 94: -0.05284042853975515
# Recalibrated reward for step 95: -0.1258098496194332
# Recalibrated reward for step 96: -0.18677190552991335
# Recalibrated reward for step 97: -0.2581001047749916
# Recalibrated reward for step 98: -0.04957570254598165
# Recalibrated reward for step 99: 0.02929047866520461
# Recalibrated reward for step 100: 0.6341610619067264
# Recalibrated reward for step 101: 0.14847376856019573
# Recalibrated reward for step 102: -0.0257544287376113
# Recalibrated reward for step 103: -0.4780779553627175
# Recalibrated reward for step 104: -0.46726553131147874
# Recalibrated reward for step 105: -0.7242387937207522
# Recalibrated reward for step 106: -1.088483358410684
# Recalibrated reward for step 107: -1.1334960539653682
# Recalibrated reward for step 108: -1.2424704518078205
# Recalibrated reward for step 109: -1.1139344822162545
# Recalibrated reward for step 110: -0.9638144029188854
# Recalibrated reward for step 111: -1.1610728619867894
# Recalibrated reward for step 112: -1.2136653320568427
# Recalibrated reward for step 113: -1.087598509730217
# Recalibrated reward for step 114: -1.1728929965431325
# Recalibrated reward for step 115: -1.0044475372697073
# Recalibrated reward for step 116: -1.107113970032565
# Recalibrated reward for step 117: -1.2752656562323472
# Recalibrated reward for step 118: -1.2813983601549754
# Recalibrated reward for step 119: -1.3254939064213587
# Recalibrated reward for step 120: -1.3081096192898487
# Recalibrated reward for step 121: -1.2897817670149365
# Recalibrated reward for step 122: -1.2190308610578482
# Recalibrated reward for step 123: -1.162982999530737
# Recalibrated reward for step 124: -1.1041456654309514
# Recalibrated reward for step 125: -1.2392961235234108
# Recalibrated reward for step 126: -1.3939989547520362
# Recalibrated reward for step 127: -1.2129427307048213
# Recalibrated reward for step 128: -1.3249760633732979
# Recalibrated reward for step 129: -1.236576265396331
# Recalibrated reward for step 130: -1.1440314075361275
# Recalibrated reward for step 131: -1.3013727486457736
# Recalibrated reward for step 132: -1.3264199763914397
# Recalibrated reward for step 133: -1.3885209204555977
# Recalibrated reward for step 134: -1.3446867212846747
# Recalibrated reward for step 135: -1.308698161485099
# Recalibrated reward for step 136: -1.1840894682299135
# Recalibrated reward for step 137: -0.4066734102653366
# Recalibrated reward for step 138: 0.0474763010455652
# Recalibrated reward for step 139: -0.11390570031781222
# Recalibrated reward for step 140: -0.10717921957160811
# Recalibrated reward for step 141: -0.07361182619924257
# Recalibrated reward for step 142: -0.06121369112356974
# Recalibrated reward for step 143: -0.0759508290683588
# Recalibrated reward for step 144: -0.012361075912253883
# Recalibrated reward for step 145: -0.048211789550561754
# Recalibrated reward for step 146: -0.07931292120553189
# Recalibrated reward for step 147: -0.039307431999196105
# Recalibrated reward for step 148: -0.11219739847989268
# Recalibrated reward for step 149: -0.09726199358628648
# Recalibrated reward for step 150: 0.5552248090706029
# Recalibrated reward for step 151: 0.23079219896263203
# Recalibrated reward for step 152: -0.01190152468759259
# Recalibrated reward for step 153: -0.36437658837628956
# Recalibrated reward for step 154: -0.27869913537862034
# Recalibrated reward for step 155: -0.7504008837842502
# Recalibrated reward for step 156: -0.9063317573902725
# Recalibrated reward for step 157: -0.8877299890438065
# Recalibrated reward for step 158: -0.6659703894872038
# Recalibrated reward for step 159: -0.8152050014224885
# Recalibrated reward for step 160: -0.8177064440625381
# Recalibrated reward for step 161: -0.8692559100068828
# Recalibrated reward for step 162: -0.8554687519764578
# Recalibrated reward for step 163: -0.8182585967519654
# Recalibrated reward for step 164: -0.6832047526073652
# Recalibrated reward for step 165: -0.46137947213402053
# Recalibrated reward for step 166: -0.4431008582991164
# Recalibrated reward for step 167: -0.46160714981878653
# Recalibrated reward for step 168: -0.3895860734187962
# Recalibrated reward for step 169: -0.3917578002925011
# Recalibrated reward for step 170: -0.38001399086137455
# Recalibrated reward for step 171: -0.27149512027196393
# Recalibrated reward for step 172: -0.37277949213092554
# Recalibrated reward for step 173: -0.28862852588540033
# Recalibrated reward for step 174: -0.34852161363414963
# Recalibrated reward for step 175: -0.2866748514224615
# Recalibrated reward for step 176: -0.3923203740135631
# Recalibrated reward for step 177: -0.2397723573689233
# Recalibrated reward for step 178: -0.3597884724807497
# Recalibrated reward for step 179: -0.3134136676720047
# Recalibrated reward for step 180: -0.2597312719151306
# Recalibrated reward for step 181: -0.4179351813193432
# Recalibrated reward for step 182: -0.40978097244699396
# Recalibrated reward for step 183: -0.49306006534774954
# Recalibrated reward for step 184: -0.43414967424391715
# Recalibrated reward for step 185: -0.3987197595310165
# Recalibrated reward for step 186: -0.47456866207051945
# Recalibrated reward for step 187: -0.41991822252507155
# Recalibrated reward for step 188: -0.3480224282438694
# Recalibrated reward for step 189: -0.5568628171271467
# Recalibrated reward for step 190: -0.34807758171946424
# Recalibrated reward for step 191: -0.43277160770908635
# Recalibrated reward for step 192: -0.15592016125403674
# Recalibrated reward for step 193: -0.3410184793508909
# Recalibrated reward for step 194: -0.44917518767433195
# Recalibrated reward for step 195: -0.45277778930750595
# Recalibrated reward for step 196: -0.32100229757566573
# Recalibrated reward for step 197: -0.5009086121256858
# Recalibrated reward for step 198: -0.4898289846582572
# Recalibrated reward for step 199: -0.5485840840850003
# Recalibrated reward for step 200: 0.6209598742036184
# Recalibrated reward for step 201: 0.19875079773974713
# Recalibrated reward for step 202: -0.11729563439025498
# Recalibrated reward for step 203: -0.6028484183262981
# Recalibrated reward for step 204: -0.5699748873677839
# Recalibrated reward for step 205: -0.7871496016222914
# Recalibrated reward for step 206: -0.8126316396846193
# Recalibrated reward for step 207: -0.9710241631635076
# Recalibrated reward for step 208: -1.0324396632821249
# Recalibrated reward for step 209: -1.0470152696498567
# Recalibrated reward for step 210: -1.2398140460804397
# Recalibrated reward for step 211: -1.1861914014694692
# Recalibrated reward for step 212: -1.2211152127311484
# Recalibrated reward for step 213: -1.3015986212508321
# Recalibrated reward for step 214: -1.257433079321162
# Recalibrated reward for step 215: -1.2632194153993364
# Recalibrated reward for step 216: -1.1042387443949209
# Recalibrated reward for step 217: -1.0403331561900595
# Recalibrated reward for step 218: -0.8991253261196096
# Recalibrated reward for step 219: -1.004882728614452
# Recalibrated reward for step 220: -0.8685257256099173
# Recalibrated reward for step 221: -1.021536209796289
# Recalibrated reward for step 222: -0.9381449925591876
# Recalibrated reward for step 223: -0.8654170354511105
# Recalibrated reward for step 224: -0.6735312794724506
# Recalibrated reward for step 225: -0.6325489042963508
# Recalibrated reward for step 226: -0.31498245438645683
# Recalibrated reward for step 227: -0.2469999459060886
# Recalibrated reward for step 228: -0.08317323505593997
# Recalibrated reward for step 229: -0.0949374441116348
# Recalibrated reward for step 230: 0.04898364725659378
# Recalibrated reward for step 231: -0.007121545299995813
# Recalibrated reward for step 232: -0.11228848910704498
# Recalibrated reward for step 233: -0.11452032116333818
# Recalibrated reward for step 234: -0.2935000869471492
# Recalibrated reward for step 235: -0.18844312081405093
# Recalibrated reward for step 236: -0.27860916045689194
# Recalibrated reward for step 237: -0.21729893048694812
# Recalibrated reward for step 238: -0.11220064050913678
# Recalibrated reward for step 239: -0.06728054472224222
# Recalibrated reward for step 240: -0.18117438166442318
# Recalibrated reward for step 241: -0.13975566909844134
# Recalibrated reward for step 242: -0.009846019623635432
# Recalibrated reward for step 243: 0.15842865614474042
# Recalibrated reward for step 244: -0.1250160190230219
# Recalibrated reward for step 245: -0.03551423173789468
# Recalibrated reward for step 246: -0.06666937963614569
# Recalibrated reward for step 247: 0.022812746972781045
# Recalibrated reward for step 248: -0.13730001294988184
# Recalibrated reward for step 249: -0.14120188633385555
# Recalibrated reward for step 250: 0.3105074544962184
# Recalibrated reward for step 251: 0.21161588377682714
# Recalibrated reward for step 252: 0.038525338816521065
# Recalibrated reward for step 253: 0.08169632871532179
# Recalibrated reward for step 254: -0.03000243875630007
# Recalibrated reward for step 255: -0.39952507966408235
# Recalibrated reward for step 256: -0.730734923271889
# Recalibrated reward for step 257: -1.0875415080900748
# Recalibrated reward for step 258: -0.9865787522344859
# Recalibrated reward for step 259: -1.1798725603062634
# Recalibrated reward for step 260: -1.2426301892045402
# Recalibrated reward for step 261: -1.2515562444826702
# Recalibrated reward for step 262: -1.2088597230429539
# Recalibrated reward for step 263: -1.1840221332929233
# Recalibrated reward for step 264: -1.1716903879795943
# Recalibrated reward for step 265: -1.5409999524574962
# Recalibrated reward for step 266: -1.4197058110576917
# Recalibrated reward for step 267: -1.4803560324881528
# Recalibrated reward for step 268: -1.628467157438711
# Recalibrated reward for step 269: -1.5480692570881067
# Recalibrated reward for step 270: -1.5469964234777203
# Recalibrated reward for step 271: -1.6028650355642193
# Recalibrated reward for step 272: -1.6645725552577995
# Recalibrated reward for step 273: -1.5541173714111194
# Recalibrated reward for step 274: -1.4741522876267625
# Recalibrated reward for step 275: -1.4225262801510876
# Recalibrated reward for step 276: -1.344654385658596
# Recalibrated reward for step 277: -1.2800199318907428
# Recalibrated reward for step 278: -1.5236951836069021
# Recalibrated reward for step 279: -1.5607581851948167
# Recalibrated reward for step 280: -1.5923750863777506
# Recalibrated reward for step 281: -1.4864204031686463
# Recalibrated reward for step 282: -1.522702367718811
# Recalibrated reward for step 283: -1.6574101931889953
# Recalibrated reward for step 284: -1.5413177178395392
# Recalibrated reward for step 285: -0.12364379064776039
# Recalibrated reward for step 286: -0.03552439455458767
# Recalibrated reward for step 287: -0.08554450019182552
# Recalibrated reward for step 288: -0.04746011373754115
# Recalibrated reward for step 289: 0.07345987614853827
# Recalibrated reward for step 290: -0.05762492543346595
# Recalibrated reward for step 291: -0.034919030144471216
# Recalibrated reward for step 292: 0.013069162297317652
# Recalibrated reward for step 293: -0.06825039487544385
# Recalibrated reward for step 294: -0.06327539759688496
# Recalibrated reward for step 295: -0.20755421509334493
# Recalibrated reward for step 296: 0.002962716659844822
# Recalibrated reward for step 297: -0.02259242110749754
# Recalibrated reward for step 298: 0.03082234077952853
# Recalibrated reward for step 299: 0.004045516921594078
# Recalibrated reward for step 300: 0.5625495661043407
# Recalibrated reward for step 301: 0.4037339186570357
# Recalibrated reward for step 302: -0.22122865521976728
# Recalibrated reward for step 303: -0.37321930944159476
# Recalibrated reward for step 304: -0.704179397231847
# Recalibrated reward for step 305: -1.0478748278393075
# Recalibrated reward for step 306: -1.235606850320107
# Recalibrated reward for step 307: -1.342681255980938
# Recalibrated reward for step 308: -1.4707355666392319
# Recalibrated reward for step 309: -1.382033037129062
# Recalibrated reward for step 310: -1.4701959653088248
# Recalibrated reward for step 311: -1.4354888501662237
# Recalibrated reward for step 312: -1.341714947343335
# Recalibrated reward for step 313: -1.3160433320641685
# Recalibrated reward for step 314: -1.1802298671455234
# Recalibrated reward for step 315: -1.220817206339143
# Recalibrated reward for step 316: -1.1532044207160153
# Recalibrated reward for step 317: -1.2381141445066468
# Recalibrated reward for step 318: -1.1181760750096932
# Recalibrated reward for step 319: -1.074466326518887
# Recalibrated reward for step 320: -1.1163896477162276
# Recalibrated reward for step 321: -1.1154217696085398
# Recalibrated reward for step 322: -1.1312718296311566
# Recalibrated reward for step 323: -1.2151449902374385
# Recalibrated reward for step 324: -1.0751721924198696
# Recalibrated reward for step 325: -1.053245802120018
# Recalibrated reward for step 326: -0.9827853666977078
# Recalibrated reward for step 327: -0.9035391661817737
# Recalibrated reward for step 328: -0.8945046136354442
# Recalibrated reward for step 329: -0.8235023721999112
# Recalibrated reward for step 330: -0.817725432236738
# Recalibrated reward for step 331: -0.6676657759257797
# Recalibrated reward for step 332: -0.8700067427565688
# Recalibrated reward for step 333: -0.7138748242759502
# Recalibrated reward for step 334: -0.9398814306696774
# Recalibrated reward for step 335: -0.8995952776021815
# Recalibrated reward for step 336: -0.9032094062331683
# Recalibrated reward for step 337: -0.7683256539040485
# Recalibrated reward for step 338: -0.7140594007194023
# Recalibrated reward for step 339: -0.7549866894591972
# Recalibrated reward for step 340: -0.717478701423629
# Recalibrated reward for step 341: -0.5795920066189901
# Recalibrated reward for step 342: -0.024104003368897897
# Recalibrated reward for step 343: 0.08181077818479592
# Recalibrated reward for step 344: -0.11540064455298565
# Recalibrated reward for step 345: -0.07484871003612024
# Recalibrated reward for step 346: 0.0819060146417091
# Recalibrated reward for step 347: -0.23759634164189553
# Recalibrated reward for step 348: -0.10665758097066139
# Recalibrated reward for step 349: -0.2634937256232716
# Recalibrated reward for step 350: 0.639247798579342
# Recalibrated reward for step 351: 0.29380725110639766
# Recalibrated reward for step 352: -0.06526681810729956
# Recalibrated reward for step 353: -0.5124016100864008
# Recalibrated reward for step 354: -0.8679999534389106
# Recalibrated reward for step 355: -0.9459665239794
# Recalibrated reward for step 356: -1.2891919358960515
# Recalibrated reward for step 357: -1.2428408490532377
# Recalibrated reward for step 358: -1.238321010682791
# Recalibrated reward for step 359: -1.2389012873438736
# Recalibrated reward for step 360: -1.460257094959519
# Recalibrated reward for step 361: -1.6062954580129467
# Recalibrated reward for step 362: -1.7287564840601348
# Recalibrated reward for step 363: -1.6142447944430398
# Recalibrated reward for step 364: -1.429661572670876
# Recalibrated reward for step 365: -1.4554827217520785
# Recalibrated reward for step 366: -1.2445299771625258
# Recalibrated reward for step 367: -1.2253289344356755
# Recalibrated reward for step 368: -1.2259324111274525
# Recalibrated reward for step 369: -1.1406830963055778
# Recalibrated reward for step 370: -1.1708474344234194
# Recalibrated reward for step 371: -1.143189695895267
# Recalibrated reward for step 372: -1.0982575767063307
# Recalibrated reward for step 373: -0.9689982204319347
# Recalibrated reward for step 374: -0.9379601574682218
# Recalibrated reward for step 375: -0.9927888298456136
# Recalibrated reward for step 376: -1.0571691269591403
# Recalibrated reward for step 377: -0.9137706784403572
# Recalibrated reward for step 378: -0.8934714622479686
# Recalibrated reward for step 379: -0.8245859341658742
# Recalibrated reward for step 380: -0.7509991951113425
# Recalibrated reward for step 381: -0.6514816029666638
# Recalibrated reward for step 382: -0.5423515736864997
# Recalibrated reward for step 383: -0.46839991523382146
# Recalibrated reward for step 384: -0.42790665151400803
# Recalibrated reward for step 385: -0.3806883873076254
# Recalibrated reward for step 386: -0.3432579434382153
# Recalibrated reward for step 387: -0.25104291535285017
# Recalibrated reward for step 388: -0.17172167592342522
# Recalibrated reward for step 389: -0.21522595371771555
# Recalibrated reward for step 390: -0.13747197945173198
# Recalibrated reward for step 391: -0.10460267770413036
# Recalibrated reward for step 392: -0.0022087153365792644
# Recalibrated reward for step 393: 0.07641509536330071
# Recalibrated reward for step 394: 0.14629537673503976
# Recalibrated reward for step 395: -0.102080660806841
# Recalibrated reward for step 396: 0.0011284952020923153
# Recalibrated reward for step 397: 0.025625678190136475
# Recalibrated reward for step 398: -0.005554273321338961
# Recalibrated reward for step 399: -0.10747447761101597
# Recalibrated reward for step 400: 0.21736652686053204
# Recalibrated reward for step 401: 0.24650827711981887
# Recalibrated reward for step 402: 0.0005670761265997581
# Recalibrated reward for step 403: -0.02160189358952705
# Recalibrated reward for step 404: 0.07876049415840819
# Recalibrated reward for step 405: 0.08520671618084855
# Recalibrated reward for step 406: 0.02788795390580598
# Recalibrated reward for step 407: -0.029704067047730223
# Recalibrated reward for step 408: 0.12097645474469242
# Recalibrated reward for step 409: -0.13805636294657664
# Recalibrated reward for step 410: 0.07976575864809864
# Recalibrated reward for step 411: -0.29741166259530455
# Recalibrated reward for step 412: -0.2314415132086705
# Recalibrated reward for step 413: -0.3650724614746352
# Recalibrated reward for step 414: -0.22226218815698723
# Recalibrated reward for step 415: -0.1675098569642957
# Recalibrated reward for step 416: -0.13310683500845172
# Recalibrated reward for step 417: -0.1189743680509332
# Recalibrated reward for step 418: -0.2998657353057697
# Recalibrated reward for step 419: -0.32570495635285396
# Recalibrated reward for step 420: -0.4464032871995396
# Recalibrated reward for step 421: -0.39812844640184625
# Recalibrated reward for step 422: -0.4384247731598111
# Recalibrated reward for step 423: -0.3198543348149946
# Recalibrated reward for step 424: -0.3124907931176419
# Recalibrated reward for step 425: -0.2437742513032604
# Recalibrated reward for step 426: -0.3225987296412378
# Recalibrated reward for step 427: -0.13538924743688674
# Recalibrated reward for step 428: -0.5067117086592918
# Recalibrated reward for step 429: -0.5608569440067542
# Recalibrated reward for step 430: -0.5392274328596515
# Recalibrated reward for step 431: -0.4826665216984137
# Recalibrated reward for step 432: -0.5119672744384857
# Recalibrated reward for step 433: -0.31969390286316185
# Recalibrated reward for step 434: -0.5051301138080847
# Recalibrated reward for step 435: -0.6811476717846519
# Recalibrated reward for step 436: -0.5825272939012978
# Recalibrated reward for step 437: -0.7505018884240388
# Recalibrated reward for step 438: -0.6245733450513434
# Recalibrated reward for step 439: -0.7255290785779946
# Recalibrated reward for step 440: -0.6946126659401365
# Recalibrated reward for step 441: -0.7345544163133231
# Recalibrated reward for step 442: -0.8399641182310023
# Recalibrated reward for step 443: -0.6862076333501952
# Recalibrated reward for step 444: -0.7924381660403691
# Recalibrated reward for step 445: -0.7671633236374799
# Recalibrated reward for step 446: -0.701695999100868
# Recalibrated reward for step 447: -0.7839704771563571
# Recalibrated reward for step 448: -0.559536165654816
# Recalibrated reward for step 449: -0.9445591532521104
# Recalibrated reward for step 450: 0.7673783546323136
# Recalibrated reward for step 451: 0.2124847636039458
# Recalibrated reward for step 452: -0.2359814838740416
# Recalibrated reward for step 453: -0.5371091442164138
# Recalibrated reward for step 454: -0.7897389852108239
# Recalibrated reward for step 455: -1.1832109283338015
# Recalibrated reward for step 456: -1.1268063602985312
# Recalibrated reward for step 457: -1.2215775794212576
# Recalibrated reward for step 458: -1.181168300544477
# Recalibrated reward for step 459: -1.2190938295425593
# Recalibrated reward for step 460: -1.0412127378926612
# Recalibrated reward for step 461: -1.1942909816520875
# Recalibrated reward for step 462: -1.0954913886995503
# Recalibrated reward for step 463: -0.9663686408698556
# Recalibrated reward for step 464: -0.9690495360994191
# Recalibrated reward for step 465: -0.8916346627495151
# Recalibrated reward for step 466: -0.9844898766370485
# Recalibrated reward for step 467: -0.7616760327177677
# Recalibrated reward for step 468: -0.8102328593708876
# Recalibrated reward for step 469: -0.9408380923408636
# Recalibrated reward for step 470: -0.7877581687724268
# Recalibrated reward for step 471: -0.8296412375003883
# Recalibrated reward for step 472: -0.683781461195802
# Recalibrated reward for step 473: -0.681220663352509
# Recalibrated reward for step 474: -0.7798481939228857
# Recalibrated reward for step 475: -0.8854303495790448
# Recalibrated reward for step 476: -0.8175551709953145
# Recalibrated reward for step 477: -0.8495387577329878
# Recalibrated reward for step 478: -0.8258062496498482
# Recalibrated reward for step 479: -0.7991554380961143
# Recalibrated reward for step 480: -0.6478203339520288
# Recalibrated reward for step 481: -0.5005364151288749
# Recalibrated reward for step 482: -0.4405741570336912
# Recalibrated reward for step 483: -0.4392752451539766
# Recalibrated reward for step 484: -0.3744496215439887
# Recalibrated reward for step 485: -0.3510910091679515
# Recalibrated reward for step 486: -0.35235986827289845
# Recalibrated reward for step 487: -0.32569716145817434
# Recalibrated reward for step 488: -0.21284857090264528
# Recalibrated reward for step 489: -0.08580335520628524
# Recalibrated reward for step 490: -0.3045131659596755
# Recalibrated reward for step 491: -0.15985874890394286
# Recalibrated reward for step 492: -0.45730056856618884
# Recalibrated reward for step 493: -0.31978037881070664
# Recalibrated reward for step 494: -0.25083345934202167
# Recalibrated reward for step 495: -0.1813596251980843
# Recalibrated reward for step 496: -0.17886409027042088
# Recalibrated reward for step 497: -0.08148755347516587
# Recalibrated reward for step 498: -0.2547952828438804
# Recalibrated reward for step 499: -0.02798787832285364
# Recalibrated reward for step 500: 0.6699876782273386
# Recalibrated reward for step 501: 0.257679636343572
# Recalibrated reward for step 502: -0.01605134988616752
# Recalibrated reward for step 503: -0.38848254651692593
# Recalibrated reward for step 504: -0.8674870419383166
# Recalibrated reward for step 505: -0.798296708816445
# Recalibrated reward for step 506: -1.1723959630475098
# Recalibrated reward for step 507: -1.0740973517801993
# Recalibrated reward for step 508: -0.9706370898262277
# Recalibrated reward for step 509: -1.0813510359940919
# Recalibrated reward for step 510: -0.9144689607988178
# Recalibrated reward for step 511: -0.9459136165370164
# Recalibrated reward for step 512: -0.7010098473745273
# Recalibrated reward for step 513: -0.7045012349710236
# Recalibrated reward for step 514: -0.5119388782120404
# Recalibrated reward for step 515: -0.5087469224507475
# Recalibrated reward for step 516: -0.6386754630006466
# Recalibrated reward for step 517: -0.5364045296472175
# Recalibrated reward for step 518: -0.45914044021243916
# Recalibrated reward for step 519: -0.2976282905773854
# Recalibrated reward for step 520: -0.37899907561607743
# Recalibrated reward for step 521: -0.3572365748879516
# Recalibrated reward for step 522: -0.4127087580611353
# Recalibrated reward for step 523: -0.36080070193191277
# Recalibrated reward for step 524: -0.3296345276777373
# Recalibrated reward for step 525: -0.3728252724867166
# Recalibrated reward for step 526: -0.25555833236040987
# Recalibrated reward for step 527: -0.31187328339064785
# Recalibrated reward for step 528: -0.0639815439760016
# Recalibrated reward for step 529: -0.14450914045191254
# Recalibrated reward for step 530: -0.21713713833697787
# Recalibrated reward for step 531: -0.1274449435339125
# Recalibrated reward for step 532: -0.2590129625920148
# Recalibrated reward for step 533: -0.17728772105494092
# Recalibrated reward for step 534: -0.2040226447689825
# Recalibrated reward for step 535: -0.06984398842370068
# Recalibrated reward for step 536: -0.21329978236762104
# Recalibrated reward for step 537: -0.18937899231589914
# Recalibrated reward for step 538: -0.17818598606201483
# Recalibrated reward for step 539: -0.12820452638442142
# Recalibrated reward for step 540: -0.040488626693181776
# Recalibrated reward for step 541: -0.09150117002879882
# Recalibrated reward for step 542: -0.12841073172146633
# Recalibrated reward for step 543: -0.17150247724514822
# Recalibrated reward for step 544: -0.22469871283833961
# Recalibrated reward for step 545: -0.1039867438103661
# Recalibrated reward for step 546: -0.08044205341454769
# Recalibrated reward for step 547: -0.26813402069108727
# Recalibrated reward for step 548: -0.3356380273679397
# Recalibrated reward for step 549: -0.3530344765728024
# Recalibrated reward for step 550: 0.6288765722039118
# Recalibrated reward for step 551: 0.21421402489764552
# Recalibrated reward for step 552: -0.14958815677341372
# Recalibrated reward for step 553: -0.4591212152509965
# Recalibrated reward for step 554: -0.7549192207913987
# Recalibrated reward for step 555: -0.66517059642446
# Recalibrated reward for step 556: -0.7598704304493247
# Recalibrated reward for step 557: -0.7475839809321003
# Recalibrated reward for step 558: -0.5827516105318004
# Recalibrated reward for step 559: -0.7725679244366198
# Recalibrated reward for step 560: -0.7478642340310138
# Recalibrated reward for step 561: -0.6352232098605638
# Recalibrated reward for step 562: -0.5381828885342491
# Recalibrated reward for step 563: -0.62025002024441
# Recalibrated reward for step 564: -0.5255915039448539
# Recalibrated reward for step 565: -0.37984475318803385
# Recalibrated reward for step 566: -0.3644453713790599
# Recalibrated reward for step 567: -0.3627516618843858
# Recalibrated reward for step 568: -0.4159267827834932
# Recalibrated reward for step 569: -0.24385030178716272
# Recalibrated reward for step 570: -0.15148846546976194
# Recalibrated reward for step 571: -0.20421319827454043
# Recalibrated reward for step 572: -0.038565875500406646
# Recalibrated reward for step 573: -0.3600007235237544
# Recalibrated reward for step 574: -0.24383702780060645
# Recalibrated reward for step 575: -0.11903459559552086
# Recalibrated reward for step 576: -0.1785003288934115
# Recalibrated reward for step 577: -0.12642636689183112
# Recalibrated reward for step 578: -0.018704227644885857
# Recalibrated reward for step 579: 0.07216207562836041
# Recalibrated reward for step 580: 0.2634548919996583
# Recalibrated reward for step 581: -0.04765789050814826
# Recalibrated reward for step 582: 0.04038314595762649
# Recalibrated reward for step 583: -0.017685570444684075
# Recalibrated reward for step 584: -0.11381168903724691
# Recalibrated reward for step 585: -0.22580736660609127
# Recalibrated reward for step 586: 0.03774406142976313
# Recalibrated reward for step 587: -0.3305525754106057
# Recalibrated reward for step 588: -0.16164190336996395
# Recalibrated reward for step 589: -0.07705379230534373
# Recalibrated reward for step 590: -0.04278993193670022
# Recalibrated reward for step 591: 0.02073863188174191
# Recalibrated reward for step 592: 0.14380071587979035
# Recalibrated reward for step 593: 0.017418634144120183
# Recalibrated reward for step 594: 0.1846058864653481
# Recalibrated reward for step 595: 0.1188790291551687
# Recalibrated reward for step 596: -0.2364399445174299
# Recalibrated reward for step 597: -0.1956016711294816
# Recalibrated reward for step 598: -0.21662006706521497
# Recalibrated reward for step 599: -0.22827059699578472
# Recalibrated reward for step 600: 0.5900634891322917
# Recalibrated reward for step 601: 0.439806306121121
# Recalibrated reward for step 602: 0.19520964738401458
# Recalibrated reward for step 603: -0.028207413263716397
# Recalibrated reward for step 604: -0.5306023641838089
# Recalibrated reward for step 605: -0.9296542904950882
# Recalibrated reward for step 606: -1.223047345924767
# Recalibrated reward for step 607: -1.603035103514074
# Recalibrated reward for step 608: -1.6269075476099881
# Recalibrated reward for step 609: -1.8338660798696
# Recalibrated reward for step 610: -1.948320960949753
# Recalibrated reward for step 611: -2.2465800089599135
# Recalibrated reward for step 612: -2.1955642462933405
# Recalibrated reward for step 613: -2.273450672317322
# Recalibrated reward for step 614: -2.4574799904302678
# Recalibrated reward for step 615: -2.411979539966499
# Recalibrated reward for step 616: -2.3886093283800074
# Recalibrated reward for step 617: -2.3372698094288533
# Recalibrated reward for step 618: -2.3644099979125857
# Recalibrated reward for step 619: -2.4160835306891193
# Recalibrated reward for step 620: -2.454560954345425
# Recalibrated reward for step 621: -2.2917290870457983
# Recalibrated reward for step 622: -2.1363724873207226
# Recalibrated reward for step 623: -2.191783539152557
# Recalibrated reward for step 624: 0.09161934865913295
# Recalibrated reward for step 625: -0.05028946107033974
# Recalibrated reward for step 626: -0.08009469571691485
# Recalibrated reward for step 627: -0.1744147892140318
# Recalibrated reward for step 628: -0.07289763524956759
# Recalibrated reward for step 629: -0.1387695229016861
# Recalibrated reward for step 630: -0.3046682137281056
# Recalibrated reward for step 631: -0.19921758507322587
# Recalibrated reward for step 632: -0.23217362284186593
# Recalibrated reward for step 633: -0.03324832544799387
# Recalibrated reward for step 634: -0.28219191294126994
# Recalibrated reward for step 635: -0.2584349154052704
# Recalibrated reward for step 636: -0.19368965030913873
# Recalibrated reward for step 637: -0.19269389293834188
# Recalibrated reward for step 638: -0.22348893996252372
# Recalibrated reward for step 639: -0.18113132730380355
# Recalibrated reward for step 640: -0.15963019399449954
# Recalibrated reward for step 641: -0.14141704078123363
# Recalibrated reward for step 642: -0.11156169584123625
# Recalibrated reward for step 643: -0.010782656619919992
# Recalibrated reward for step 644: 0.028366780887696813
# Recalibrated reward for step 645: -0.0994789292008249
# Recalibrated reward for step 646: -0.09403872352915227
# Recalibrated reward for step 647: -0.008382372853280987
# Recalibrated reward for step 648: -0.1288947900891236
# Recalibrated reward for step 649: -0.28696721291584576
# Recalibrated reward for step 650: 0.6507029269000095
# Recalibrated reward for step 651: 0.5587087661520005
# Recalibrated reward for step 652: -0.0831704880712924
# Recalibrated reward for step 653: -0.32092176847190806
# Recalibrated reward for step 654: -0.7424444593117706
# Recalibrated reward for step 655: -1.148383668977241
# Recalibrated reward for step 656: -1.1586471105175082
# Recalibrated reward for step 657: -1.6592390927417187
# Recalibrated reward for step 658: -1.6674875983938116
# Recalibrated reward for step 659: -1.9372166177792267
# Recalibrated reward for step 660: -1.7401494248665939
# Recalibrated reward for step 661: -1.9345220114414283
# Recalibrated reward for step 662: -2.0925451214808204
# Recalibrated reward for step 663: -2.159659604989974
# Recalibrated reward for step 664: -2.2044436501544977
# Recalibrated reward for step 665: -2.006314552537577
# Recalibrated reward for step 666: -1.817968959053847
# Recalibrated reward for step 667: -1.9505713194727439
# Recalibrated reward for step 668: -1.7754940857931871
# Recalibrated reward for step 669: -1.962437253031839
# Recalibrated reward for step 670: -1.9333981370985802
# Recalibrated reward for step 671: -1.8991393949587083
# Recalibrated reward for step 672: -1.9469181917068696
# Recalibrated reward for step 673: -1.8613924377765383
# Recalibrated reward for step 674: -1.7638971828591883
# Recalibrated reward for step 675: -1.876700317399873
# Recalibrated reward for step 676: -1.5141949828206207
# Recalibrated reward for step 677: 0.08445695287473703
# Recalibrated reward for step 678: -0.09418852597484395
# Recalibrated reward for step 679: -0.16094531390961242
# Recalibrated reward for step 680: -0.0908813339561935
# Recalibrated reward for step 681: -0.04615738725005683
# Recalibrated reward for step 682: -0.06988631103185199
# Recalibrated reward for step 683: -0.22476958038177458
# Recalibrated reward for step 684: -0.13857740849333175
# Recalibrated reward for step 685: -0.1750978822592686
# Recalibrated reward for step 686: -0.2630991791219742
# Recalibrated reward for step 687: -0.16216191831255844
# Recalibrated reward for step 688: -0.15020921530284087
# Recalibrated reward for step 689: -0.14224866057182067
# Recalibrated reward for step 690: -0.032388933494658406
# Recalibrated reward for step 691: -0.021469109356873767
# Recalibrated reward for step 692: -0.10159827113246031
# Recalibrated reward for step 693: -0.10496753527230628
# Recalibrated reward for step 694: 0.006865365007531557
# Recalibrated reward for step 695: -0.10291545364507916
# Recalibrated reward for step 696: -0.04781784962805716
# Recalibrated reward for step 697: 0.005494568302035874
# Recalibrated reward for step 698: -0.13534283727316537
# Recalibrated reward for step 699: 0.06125608458170488
# Recalibrated reward for step 700: 0.494615380504158
# Recalibrated reward for step 701: 0.04652139722908255
# Recalibrated reward for step 702: -0.12892165483280474
# Recalibrated reward for step 703: -0.1704011398631681
# Recalibrated reward for step 704: -0.4534019452676026
# Recalibrated reward for step 705: -0.4243831804804029
# Recalibrated reward for step 706: -0.43936802821619575
# Recalibrated reward for step 707: -0.5600266420990544
# Recalibrated reward for step 708: -0.5092655273974009
# Recalibrated reward for step 709: -0.4495017489429108
# Recalibrated reward for step 710: -0.4046341073793076
# Recalibrated reward for step 711: -0.36452892113653
# Recalibrated reward for step 712: -0.3929468000918531
# Recalibrated reward for step 713: -0.2527965679402434
# Recalibrated reward for step 714: -0.35908111534110243
# Recalibrated reward for step 715: -0.30984396031729416
# Recalibrated reward for step 716: -0.3610881559792195
# Recalibrated reward for step 717: -0.24847113134392562
# Recalibrated reward for step 718: -0.49545564920834817
# Recalibrated reward for step 719: -0.46136663377608156
# Recalibrated reward for step 720: -0.4443455086742408
# Recalibrated reward for step 721: -0.5255451464702842
# Recalibrated reward for step 722: -0.5118696919667969
# Recalibrated reward for step 723: -0.5431008322968667
# Recalibrated reward for step 724: -0.42722523388721095
# Recalibrated reward for step 725: -0.6262669963443949
# Recalibrated reward for step 726: -0.5088230130368611
# Recalibrated reward for step 727: -0.5012173525877404
# Recalibrated reward for step 728: -0.5679879741714744
# Recalibrated reward for step 729: -0.4496515178352887
# Recalibrated reward for step 730: -0.542394328519637
# Recalibrated reward for step 731: -0.5657610422508297
# Recalibrated reward for step 732: -0.4254910065038788
# Recalibrated reward for step 733: -0.7723888680927993
# Recalibrated reward for step 734: -0.7987103542742493
# Recalibrated reward for step 735: -0.7559777810919175
# Recalibrated reward for step 736: -0.7029565709646389
# Recalibrated reward for step 737: -0.8600838696140782
# Recalibrated reward for step 738: -0.8502286269607036
# Recalibrated reward for step 739: -0.8490935381534175
# Recalibrated reward for step 740: -0.867901604728772
# Recalibrated reward for step 741: -0.6075938683109557
# Recalibrated reward for step 742: -0.926443139653889
# Recalibrated reward for step 743: -0.7542243953751153
# Recalibrated reward for step 744: -0.7699093581188046
# Recalibrated reward for step 745: -0.9191193195351565
# Recalibrated reward for step 746: -0.8073741814347934
# Recalibrated reward for step 747: -0.7337581373712011
# Recalibrated reward for step 748: -0.702485956804684
# Recalibrated reward for step 749: -0.7141426652389754
# Recalibrated reward for step 750: 0.21058611024085597
# Recalibrated reward for step 751: 0.2929178263127524
# Recalibrated reward for step 752: 0.14079541178965702
# Recalibrated reward for step 753: 0.2210773605430379
# Recalibrated reward for step 754: 0.16437482140728424
# Recalibrated reward for step 755: -0.0003151466274418091
# Recalibrated reward for step 756: -0.24301332079560573
# Recalibrated reward for step 757: -0.4209334759479335
# Recalibrated reward for step 758: -0.4880927248091106
# Recalibrated reward for step 759: -0.6127946119015888
# Recalibrated reward for step 760: -0.5439411857203696
# Recalibrated reward for step 761: -0.64412027282533
# Recalibrated reward for step 762: -0.41446858443476037
# Recalibrated reward for step 763: -0.7341380784013242
# Recalibrated reward for step 764: -0.7313287790674668
# Recalibrated reward for step 765: -0.5325020341948546
# Recalibrated reward for step 766: -0.6054593624989784
# Recalibrated reward for step 767: -0.5061048860086779
# Recalibrated reward for step 768: -0.48338757515091624
# Recalibrated reward for step 769: -0.5045380989788693
# Recalibrated reward for step 770: -0.3950239669936826
# Recalibrated reward for step 771: -0.43476442057312437
# Recalibrated reward for step 772: -0.4024164257915821
# Recalibrated reward for step 773: -0.589564119443734
# Recalibrated reward for step 774: -0.5345952864998813
# Recalibrated reward for step 775: -0.5251094185424243
# Recalibrated reward for step 776: -0.4976766230597783
# Recalibrated reward for step 777: -0.5248244786763633
# Recalibrated reward for step 778: -0.71624818489997
# Recalibrated reward for step 779: -0.581355835346871
# Recalibrated reward for step 780: -0.7512531795779923
# Recalibrated reward for step 781: -0.5258422535257581
# Recalibrated reward for step 782: -0.7391107026213187
# Recalibrated reward for step 783: -0.6097449625042387
# Recalibrated reward for step 784: -0.6303721211470183
# Recalibrated reward for step 785: -0.5756086985767213
# Recalibrated reward for step 786: -0.6501123898775807
# Recalibrated reward for step 787: -0.7231338801148403
# Recalibrated reward for step 788: -0.5015444882130279
# Recalibrated reward for step 789: -0.7506187648426722
# Recalibrated reward for step 790: -0.6346015541261474
# Recalibrated reward for step 791: -0.6396058408584844
# Recalibrated reward for step 792: -0.6463025088348192
# Recalibrated reward for step 793: -0.7857182539679574
# Recalibrated reward for step 794: -0.7637341460828814
# Recalibrated reward for step 795: -0.9125293701535282
# Recalibrated reward for step 796: -0.7632555875254242
# Recalibrated reward for step 797: -0.6196255105572228
# Recalibrated reward for step 798: -0.8834318695254842
# Recalibrated reward for step 799: -0.8929045102537907
# Recalibrated reward for step 800: 0.6791664548679861
# Recalibrated reward for step 801: 0.5531615240297147
# Recalibrated reward for step 802: 0.25145097273602646
# Recalibrated reward for step 803: -0.27258620164414127
# Recalibrated reward for step 804: -0.6514261464149025
# Recalibrated reward for step 805: -0.8592276897558049
# Recalibrated reward for step 806: -1.2783760083404974
# Recalibrated reward for step 807: -1.368355986124934
# Recalibrated reward for step 808: -1.6355907926591364
# Recalibrated reward for step 809: -1.7286640910124917
# Recalibrated reward for step 810: -1.8519720585901545
# Recalibrated reward for step 811: -1.912438053534363
# Recalibrated reward for step 812: -1.9288607227519887
# Recalibrated reward for step 813: -1.7907598997740877
# Recalibrated reward for step 814: -2.244708682202607
# Recalibrated reward for step 815: -1.9904312324917883
# Recalibrated reward for step 816: -1.8992494449579433
# Recalibrated reward for step 817: -1.7672477290726003
# Recalibrated reward for step 818: -1.8564518547829112
# Recalibrated reward for step 819: -1.9148089083219964
# Recalibrated reward for step 820: -1.8834208111402788
# Recalibrated reward for step 821: -1.6725185945879453
# Recalibrated reward for step 822: -1.6416812772101328
# Recalibrated reward for step 823: -1.7357118362552486
# Recalibrated reward for step 824: -1.4835012113552333
# Recalibrated reward for step 825: -1.46035253004818
# Recalibrated reward for step 826: -1.3789630491564817
# Recalibrated reward for step 827: -1.3612365449417838
# Recalibrated reward for step 828: -0.11675775943308628
# Recalibrated reward for step 829: 0.11783979694742594
# Recalibrated reward for step 830: 0.14267312273871274
# Recalibrated reward for step 831: -0.08060118103811559
# Recalibrated reward for step 832: -0.23661516170324803
# Recalibrated reward for step 833: -0.14648048068864575
# Recalibrated reward for step 834: -0.30657034077810363
# Recalibrated reward for step 835: -0.07614102001510015
# Recalibrated reward for step 836: -0.23859233852751227
# Recalibrated reward for step 837: -0.2932944862913366
# Recalibrated reward for step 838: -0.3479766768678554
# Recalibrated reward for step 839: -0.2881772568611179
# Recalibrated reward for step 840: -0.09111349415877759
# Recalibrated reward for step 841: -0.35841782707080927
# Recalibrated reward for step 842: -0.3380847744910712
# Recalibrated reward for step 843: -0.27842685773618
# Recalibrated reward for step 844: -0.1588181331593439
# Recalibrated reward for step 845: -0.13657766401837018
# Recalibrated reward for step 846: 0.0908574665172723
# Recalibrated reward for step 847: -0.10287415431048422
# Recalibrated reward for step 848: -0.07887749436031208
# Recalibrated reward for step 849: -0.046836030054550004
# Recalibrated reward for step 850: 0.5731113734456302
# Recalibrated reward for step 851: -0.04851280813281256
# Recalibrated reward for step 852: -0.07681220599772587
# Recalibrated reward for step 853: -0.15101713996692992
# Recalibrated reward for step 854: -0.41542714530460356
# Recalibrated reward for step 855: -0.6622255690785407
# Recalibrated reward for step 856: -0.6661385111333882
# Recalibrated reward for step 857: -0.6619295528024478
# Recalibrated reward for step 858: -0.533062460623375
# Recalibrated reward for step 859: -0.4801019408559204
# Recalibrated reward for step 860: -0.44344792284524626
# Recalibrated reward for step 861: -0.3776633662867629
# Recalibrated reward for step 862: -0.3429525530563177
# Recalibrated reward for step 863: -0.42571677158421534
# Recalibrated reward for step 864: -0.33662172350928304
# Recalibrated reward for step 865: -0.37369101526707454
# Recalibrated reward for step 866: -0.2515047470656042
# Recalibrated reward for step 867: -0.33704527051780386
# Recalibrated reward for step 868: -0.4119665295984254
# Recalibrated reward for step 869: -0.3253671196154424
# Recalibrated reward for step 870: -0.3135295450199344
# Recalibrated reward for step 871: -0.208962158676642
# Recalibrated reward for step 872: -0.18720995440301083
# Recalibrated reward for step 873: -0.18405160662299877
# Recalibrated reward for step 874: 0.04313588453532369
# Recalibrated reward for step 875: -0.16295519364654976
# Recalibrated reward for step 876: -0.33856337625457
# Recalibrated reward for step 877: -0.4225646923691557
# Recalibrated reward for step 878: -0.2577181533013223
# Recalibrated reward for step 879: -0.3648996110779352
# Recalibrated reward for step 880: -0.40975092022690823
# Recalibrated reward for step 881: -0.5396351735295899
# Recalibrated reward for step 882: -0.37992138390105146
# Recalibrated reward for step 883: -0.38097262543442967
# Recalibrated reward for step 884: -0.2259412568143627
# Recalibrated reward for step 885: -0.4586139929325574
# Recalibrated reward for step 886: -0.3274368368937539
# Recalibrated reward for step 887: -0.4854587249078543
# ...
# Recalibrated reward for step 4711: -0.9910765696310664
# Recalibrated reward for step 4712: -0.8888706933566645
# Recalibrated reward for step 4713: -1.0405286391631423
# Recalibrated reward for step 4714: -0.9570039885177506
# Recalibrated reward for step 4715: -0.8813706763387914
# Recalibrated reward for step 4716: -1.0312413012561303
# Recalibrated reward for step 4717: -0.9020152946334464
# Recalibrated reward for step 4718: -0.8736780431635047
# Recalibrated reward for step 4719: -0.9284340802696569
# Recalibrated reward for step 4720: -0.7993841849626
# Recalibrated reward for step 4721: -0.9461739198057404
# Recalibrated reward for step 4722: -0.7846729066698848
# Recalibrated reward for step 4723: -0.8358671611474953
# Recalibrated reward for step 4724: -0.6719423313848224
# Recalibrated reward for step 4725: -0.6871331979480463
# Recalibrated reward for step 4726: -0.5350304061252763
# Recalibrated reward for step 4727: -0.42103329996910654
# Recalibrated reward for step 4728: -0.424020548298993
# Recalibrated reward for step 4729: -0.3445936901092594
# Recalibrated reward for step 4730: -0.34752164384700807
# Recalibrated reward for step 4731: -0.3094658933946273
# Recalibrated reward for step 4732: -0.2816579121190127
# Recalibrated reward for step 4733: -0.1630647972637982
# Recalibrated reward for step 4734: -0.31302659069493566
# Recalibrated reward for step 4735: -0.3010266901629764
# Recalibrated reward for step 4736: -0.28199646064287187
# Recalibrated reward for step 4737: -0.3015530793301142
# Recalibrated reward for step 4738: -0.24734835820259654
# Recalibrated reward for step 4739: -0.17118840788619888
# Recalibrated reward for step 4740: -0.12265243983736597
# Recalibrated reward for step 4741: -0.10848971514308217
# Recalibrated reward for step 4742: -0.11245679661916584
# Recalibrated reward for step 4743: -0.04888190765433534
# Recalibrated reward for step 4744: -0.005256638464474397
# Recalibrated reward for step 4745: 0.056803152533103224
# Recalibrated reward for step 4746: 0.024502196565906256
# Recalibrated reward for step 4747: 0.008824618262363651
# Recalibrated reward for step 4748: -0.23267903606829815
# Recalibrated reward for step 4749: -0.12067957961449731
# Recalibrated reward for step 4750: 0.5910633099965438
# Recalibrated reward for step 4751: 0.172276078922348
# Recalibrated reward for step 4752: -0.19542443847705124
# Recalibrated reward for step 4753: -0.05725430032651113
# Recalibrated reward for step 4754: -0.6900978405841014
# Recalibrated reward for step 4755: -0.6205469942472901
# Recalibrated reward for step 4756: -0.7058608374814064
# Recalibrated reward for step 4757: -0.6779576710037531
# Recalibrated reward for step 4758: -0.6393386436199548
# Recalibrated reward for step 4759: -0.6292456834053501
# Recalibrated reward for step 4760: -0.6741546362598146
# Recalibrated reward for step 4761: -0.48218044056519366
# Recalibrated reward for step 4762: -0.3085747015471954
# Recalibrated reward for step 4763: -0.46340773814584013
# Recalibrated reward for step 4764: -0.4474828782571646
# Recalibrated reward for step 4765: -0.41999891893421415
# Recalibrated reward for step 4766: -0.45273600247615226
# Recalibrated reward for step 4767: -0.38406881433210033
# Recalibrated reward for step 4768: -0.26441777161254476
# Recalibrated reward for step 4769: -0.2730150880309959
# Recalibrated reward for step 4770: -0.2726740014722933
# Recalibrated reward for step 4771: -0.2326299346112251
# Recalibrated reward for step 4772: -0.2463108002239301
# Recalibrated reward for step 4773: -0.11919024073977452
# Recalibrated reward for step 4774: -0.023797507544610658
# Recalibrated reward for step 4775: -0.03459540649859211
# Recalibrated reward for step 4776: -0.31941106182861223
# Recalibrated reward for step 4777: -0.3552035433575751
# Recalibrated reward for step 4778: -0.21471210922225087
# Recalibrated reward for step 4779: -0.4357161950678304
# Recalibrated reward for step 4780: -0.41894415635211046
# Recalibrated reward for step 4781: -0.2785990772838445
# Recalibrated reward for step 4782: -0.20444250600875802
# Recalibrated reward for step 4783: -0.3777374657494512
# Recalibrated reward for step 4784: -0.2673538043602356
# Recalibrated reward for step 4785: -0.0693572995580262
# Recalibrated reward for step 4786: -0.2900703517085821
# Recalibrated reward for step 4787: -0.3857558946213812
# Recalibrated reward for step 4788: -0.28243942054395255
# Recalibrated reward for step 4789: -0.2841446241165551
# Recalibrated reward for step 4790: -0.22747805345772
# Recalibrated reward for step 4791: -0.22682687775427945
# Recalibrated reward for step 4792: -0.18969701694495744
# Recalibrated reward for step 4793: -0.13783986704383194
# Recalibrated reward for step 4794: -0.22137990170247726
# Recalibrated reward for step 4795: -0.13652987219903379
# Recalibrated reward for step 4796: -0.1368679788690359
# Recalibrated reward for step 4797: 0.049819494325114115
# Recalibrated reward for step 4798: -0.11539507561325285
# Recalibrated reward for step 4799: -0.18232685614174415
# Recalibrated reward for step 4800: 0.6656585560414664
# Recalibrated reward for step 4801: 0.2445188186099746
# Recalibrated reward for step 4802: -0.2294178452752792
# Recalibrated reward for step 4803: -0.6669640787050136
# Recalibrated reward for step 4804: -0.8526706033279609
# Recalibrated reward for step 4805: -0.9585122018414656
# Recalibrated reward for step 4806: -0.8979310343509767
# Recalibrated reward for step 4807: -1.4899109977234202
# Recalibrated reward for step 4808: -1.4526761016369028
# Recalibrated reward for step 4809: -1.4198602970073182
# Recalibrated reward for step 4810: -1.2803277808488596
# Recalibrated reward for step 4811: -1.1274061645922804
# Recalibrated reward for step 4812: -1.2166264355432244
# Recalibrated reward for step 4813: -1.1779211090677715
# Recalibrated reward for step 4814: -1.4251951388385866
# Recalibrated reward for step 4815: -1.2647569362010223
# Recalibrated reward for step 4816: -1.2191685293196584
# Recalibrated reward for step 4817: -1.2183088950429855
# Recalibrated reward for step 4818: -1.0279626998656735
# Recalibrated reward for step 4819: -1.2481517008178473
# Recalibrated reward for step 4820: -1.274284483469304
# Recalibrated reward for step 4821: -1.0425049864876554
# Recalibrated reward for step 4822: -0.96621710361199
# Recalibrated reward for step 4823: -0.9635552706121165
# Recalibrated reward for step 4824: -0.9160256914085819
# Recalibrated reward for step 4825: -0.7351995566185705
# Recalibrated reward for step 4826: -0.6272833002270727
# Recalibrated reward for step 4827: -0.6369591561752831
# Recalibrated reward for step 4828: -0.5326507004780119
# Recalibrated reward for step 4829: -0.5692476698901817
# Recalibrated reward for step 4830: -0.5375302277366827
# Recalibrated reward for step 4831: -0.513284743639288
# Recalibrated reward for step 4832: -0.34615688321067917
# Recalibrated reward for step 4833: -0.5084991230244222
# Recalibrated reward for step 4834: -0.4460493870794529
# Recalibrated reward for step 4835: -0.43171721968199084
# Recalibrated reward for step 4836: -0.5435535713684072
# Recalibrated reward for step 4837: -0.4978233233187541
# Recalibrated reward for step 4838: -0.3000292028431502
# Recalibrated reward for step 4839: -0.1672126902755229
# Recalibrated reward for step 4840: -0.09161865010680637
# Recalibrated reward for step 4841: -0.21538448950263372
# Recalibrated reward for step 4842: -0.1506078121057955
# Recalibrated reward for step 4843: -0.011551791066456311
# Recalibrated reward for step 4844: 0.09105112550323069
# Recalibrated reward for step 4845: 0.1983226580946198
# Recalibrated reward for step 4846: 0.14567899922133112
# Recalibrated reward for step 4847: -0.08375233129957438
# Recalibrated reward for step 4848: -0.021121244831531848
# Recalibrated reward for step 4849: 0.00709236717389445
# Recalibrated reward for step 4850: 0.6737986621891764
# Recalibrated reward for step 4851: 0.4246339024275052
# Recalibrated reward for step 4852: -0.054973480097391
# Recalibrated reward for step 4853: -0.3093444172953714
# Recalibrated reward for step 4854: -0.5909570964207664
# Recalibrated reward for step 4855: -1.0009721140634469
# Recalibrated reward for step 4856: -1.0266483275354181
# Recalibrated reward for step 4857: -1.055583023026808
# Recalibrated reward for step 4858: -0.9899351096220795
# Recalibrated reward for step 4859: -1.074397989936799
# Recalibrated reward for step 4860: -0.8688931827017539
# Recalibrated reward for step 4861: -1.129162314439167
# Recalibrated reward for step 4862: -1.0335802873956437
# Recalibrated reward for step 4863: -0.9549975663515953
# Recalibrated reward for step 4864: -1.1012992778583865
# Recalibrated reward for step 4865: -0.9508830833304946
# Recalibrated reward for step 4866: -0.844886161611513
# Recalibrated reward for step 4867: -0.8242927982967015
# Recalibrated reward for step 4868: -0.8485727455791383
# Recalibrated reward for step 4869: -0.7587092066847113
# Recalibrated reward for step 4870: -0.6871713939880878
# Recalibrated reward for step 4871: -0.6528398404231746
# Recalibrated reward for step 4872: -0.5432994362633635
# Recalibrated reward for step 4873: -0.43933978663382256
# Recalibrated reward for step 4874: -0.35179990055573607
# Recalibrated reward for step 4875: -0.313519951133961
# Recalibrated reward for step 4876: -0.35649777651743597
# Recalibrated reward for step 4877: -0.33451835316511935
# Recalibrated reward for step 4878: -0.32682231951733987
# Recalibrated reward for step 4879: -0.1434934694354992
# Recalibrated reward for step 4880: -0.3291461106007364
# Recalibrated reward for step 4881: -0.2525528731771595
# Recalibrated reward for step 4882: -0.24923415022851672
# Recalibrated reward for step 4883: -0.17512018438089644
# Recalibrated reward for step 4884: -0.23915580166546402
# Recalibrated reward for step 4885: -0.3087582687061548
# Recalibrated reward for step 4886: -0.23608990446735298
# Recalibrated reward for step 4887: -0.19417700143566097
# Recalibrated reward for step 4888: -0.361675377944576
# Recalibrated reward for step 4889: -0.28783360103388783
# Recalibrated reward for step 4890: -0.17547542270910294
# Recalibrated reward for step 4891: -0.3740817129359173
# Recalibrated reward for step 4892: -0.2421914271091404
# Recalibrated reward for step 4893: -0.056131166465207744
# Recalibrated reward for step 4894: 0.04819412168181055
# Recalibrated reward for step 4895: -0.05523231976653473
# Recalibrated reward for step 4896: -0.20151857724664665
# Recalibrated reward for step 4897: -0.10070721530553604
# Recalibrated reward for step 4898: -0.2222874104208068
# Recalibrated reward for step 4899: -0.2073156896283203
# Recalibrated reward for step 4900: 0.5296052857365582
# Recalibrated reward for step 4901: 0.4270271505609409
# Recalibrated reward for step 4902: 0.15217105657967211
# Recalibrated reward for step 4903: -0.1495070810737381
# Recalibrated reward for step 4904: -0.7156072892965952
# Recalibrated reward for step 4905: -0.8332938467915858
# Recalibrated reward for step 4906: -0.917425170765649
# Recalibrated reward for step 4907: -1.1660465356776755
# Recalibrated reward for step 4908: -1.1452329679126283
# Recalibrated reward for step 4909: -0.9687210639496819
# Recalibrated reward for step 4910: -0.9841993023735353
# Recalibrated reward for step 4911: -0.9463973056124997
# Recalibrated reward for step 4912: -0.9093023155822513
# Recalibrated reward for step 4913: -0.8350339321766463
# Recalibrated reward for step 4914: -0.7339325762312947
# Recalibrated reward for step 4915: -0.7237288923076187
# Recalibrated reward for step 4916: -0.6759440381046866
# Recalibrated reward for step 4917: -0.7341303132573261
# Recalibrated reward for step 4918: -0.6774966328075026
# Recalibrated reward for step 4919: -0.6154371352235279
# Recalibrated reward for step 4920: -0.48200886819142974
# Recalibrated reward for step 4921: -0.4985236894074946
# Recalibrated reward for step 4922: -0.5638923982393937
# Recalibrated reward for step 4923: -0.4125839079991287
# Recalibrated reward for step 4924: -0.6237887575756362
# Recalibrated reward for step 4925: -0.44836657999775265
# Recalibrated reward for step 4926: -0.5866517846330757
# Recalibrated reward for step 4927: -0.5631337628852278
# Recalibrated reward for step 4928: -0.5763377017769459
# Recalibrated reward for step 4929: -0.4635003733185718
# Recalibrated reward for step 4930: -0.5026957159054662
# Recalibrated reward for step 4931: -0.41713496938776023
# Recalibrated reward for step 4932: -0.5366041820784924
# Recalibrated reward for step 4933: -0.5178587646552929
# Recalibrated reward for step 4934: -0.5359751916265004
# Recalibrated reward for step 4935: -0.43198476392100443
# Recalibrated reward for step 4936: -0.426765393434005
# Recalibrated reward for step 4937: -0.41902605095970846
# Recalibrated reward for step 4938: -0.34714242404898416
# Recalibrated reward for step 4939: -0.44004121767135407
# Recalibrated reward for step 4940: -0.20801229251938388
# Recalibrated reward for step 4941: -0.2517574329336151
# Recalibrated reward for step 4942: -0.49096506588928746
# Recalibrated reward for step 4943: -0.3869105785038893
# Recalibrated reward for step 4944: -0.5455886635602119
# Recalibrated reward for step 4945: -0.439520794668989
# Recalibrated reward for step 4946: -0.4919461034918975
# Recalibrated reward for step 4947: -0.6670282004024879
# Recalibrated reward for step 4948: -0.5391459271163693
# Recalibrated reward for step 4949: -0.32102623780096623
# Recalibrated reward for step 4950: 0.21938456709804338
# Recalibrated reward for step 4951: 0.11524746039567801
# Recalibrated reward for step 4952: 0.14190798423954254
# Recalibrated reward for step 4953: -0.23869628451807523
# Recalibrated reward for step 4954: -0.20196504328437193
# Recalibrated reward for step 4955: -0.21274149208991516
# Recalibrated reward for step 4956: -0.4472832012892349
# Recalibrated reward for step 4957: -0.36731857296337334
# Recalibrated reward for step 4958: -0.3387318377024687
# Recalibrated reward for step 4959: -0.16032106878122218
# Recalibrated reward for step 4960: -0.1657153689533366
# Recalibrated reward for step 4961: -0.15258562627432948
# Recalibrated reward for step 4962: -0.061986859864855054
# Recalibrated reward for step 4963: -0.03174318445430875
# Recalibrated reward for step 4964: -0.08711452452678908
# Recalibrated reward for step 4965: 0.06682837889753594
# Recalibrated reward for step 4966: 0.06242946700625371
# Recalibrated reward for step 4967: 0.25147852380213515
# Recalibrated reward for step 4968: -0.1536918211429314
# Recalibrated reward for step 4969: -0.14039804155286834
# Recalibrated reward for step 4970: 0.09427598007840114
# Recalibrated reward for step 4971: 0.02686443723883067
# Recalibrated reward for step 4972: 0.014025212376202158
# Recalibrated reward for step 4973: 0.09601765352776168
# Recalibrated reward for step 4974: 0.09448450934144627
# Recalibrated reward for step 4975: -0.03665925116244184
# Recalibrated reward for step 4976: 0.11904289171934594
# Recalibrated reward for step 4977: -0.06827552568238021
# Recalibrated reward for step 4978: 0.14372891318265735
# Recalibrated reward for step 4979: -0.25490026959880036
# Recalibrated reward for step 4980: -0.17514721250113552
# Recalibrated reward for step 4981: -0.23574726036556598
# Recalibrated reward for step 4982: -0.07839558534114272
# Recalibrated reward for step 4983: -0.3007432320672736
# Recalibrated reward for step 4984: -0.2551005066827185
# Recalibrated reward for step 4985: -0.17240329773454988
# Recalibrated reward for step 4986: -0.038110391983767186
# Recalibrated reward for step 4987: -0.13341163059733743
# Recalibrated reward for step 4988: -0.27437440741875924
# Recalibrated reward for step 4989: -0.2157567746057822
# Recalibrated reward for step 4990: -0.21596869690996695
# Recalibrated reward for step 4991: -0.16635952388489125
# Recalibrated reward for step 4992: -0.16993293044241195
# Recalibrated reward for step 4993: -0.22923878113263416
# Recalibrated reward for step 4994: -0.15963398165728404
# Recalibrated reward for step 4995: -0.23128301172976762
# Recalibrated reward for step 4996: -0.3008228013534603
# Recalibrated reward for step 4997: -0.27596030452398546
# Recalibrated reward for step 4998: -0.49618970264682816
# Recalibrated reward for step 4999: -0.5007464279171003

# %%
# Step A.5.1: CUSTOM REWARD FUNCTION
def custom_reward(self, env, state, action, next_state, reward, done):
    # Access and recalculate the reward using human_feedback_data or recalibrate_rewards_human function
    global step_counter
    try:
        step_counter
    except NameError:
        step_counter = 0

    reward = recalibrated_rewards_list[step_counter]
    step_counter += 1
    return reward

# Create a new environment class that wraps your original environment and overrides the default reward function with your custom function
class CustomRewardWrapper(gym.Wrapper):
    def __init__(self, env):
        super(CustomRewardWrapper, self).__init__(env)

    def step(self, action):
        next_state, reward, terminated, truncated, info = self.env.step(action)
        done = terminated or truncated
        reward = custom_reward(self, self.env, self.last_obs, action, next_state, reward, done)
        # custom_reward should be defined and accessible to your class
        self.last_obs = next_state
        return next_state, reward, terminated, truncated, info

    def reset(self, **kwargs):
        global step_counter
        step_counter = 0
        self.last_obs = self.env.reset(**kwargs)[0]  # Assuming Gymnasium env returns (obs, info)
        return self.last_obs, {}  # Assuming Gymnasium env requires (obs, info)
# Create and wrap the environment with your custom reward wrapper
# env_human = CustomRewardWrapper(gym.make('highway-v0'))

# %% [markdown]
# PPO training and Training logs

# %%
drive_log_dir = "/content/drive/MyDrive/05_zero_shot_llm_3/03_reacher_data/00_training_logs/2_log_dir/2_ppo_reacher_hf_direct_aggressive_3"              # Update directory location 3

# %%
# Train PPO with Custom Rewards
def train_ppo_with_custom_rewards(log_dir=drive_log_dir, total_timesteps=200000):
    os.makedirs(log_dir, exist_ok=True)
    env = CustomRewardWrapper(gym.make("Reacher-v5"))
    env = Monitor(env, log_dir)
    model = PPO("MlpPolicy", env, verbose=1, tensorboard_log=log_dir)
    model.learn(total_timesteps=total_timesteps)
    model.save('/content/drive/MyDrive/05_zero_shot_llm_3/03_reacher_data/01_trained_models/2_ppo_reacher_hf_direct_aggressive_3')       # Update directory location 4
    return model, log_dir

# %%
# Execute Training and Convergence Tracking
model, log_dir = train_ppo_with_custom_rewards(total_timesteps=200000)
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# Logging to /content/drive/MyDrive/05_zero_shot_llm_3/03_reacher_data/00_training_logs/2_log_dir/2_ppo_reacher_hf_direct_aggressive_3/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -40.6    |
# | time/              |          |
# |    fps             | 1135     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -40.6        |
# | time/                   |              |
# |    fps                  | 860          |
# |    iterations           | 2            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0038318967 |
# |    clip_fraction        | 0.0284       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | -0.0192      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 42.4         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00415     |
# |    std                  | 0.999        |
# |    value_loss           | 118          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -40.6        |
# | time/                   |              |
# |    fps                  | 717          |
# |    iterations           | 3            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0037873015 |
# |    clip_fraction        | 0.015        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0.0526       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.2         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00387     |
# |    std                  | 0.993        |
# |    value_loss           | 71           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -40.6       |
# | time/                   |             |
# |    fps                  | 699         |
# |    iterations           | 4           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.004013526 |
# |    clip_fraction        | 0.0395      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.83       |
# |    explained_variance   | -0.0818     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.8        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00466    |
# |    std                  | 0.994       |
# |    value_loss           | 50.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -40.6        |
# | time/                   |              |
# |    fps                  | 699          |
# |    iterations           | 5            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0067150174 |
# |    clip_fraction        | 0.0557       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.111        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.69         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00554     |
# |    std                  | 0.984        |
# |    value_loss           | 39.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -40.6        |
# | time/                   |              |
# |    fps                  | 700          |
# |    iterations           | 6            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0060830666 |
# |    clip_fraction        | 0.0748       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.8         |
# |    explained_variance   | 0.392        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.2         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00911     |
# |    std                  | 0.978        |
# |    value_loss           | 38.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -40.6       |
# | time/                   |             |
# |    fps                  | 681         |
# |    iterations           | 7           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.007866614 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.78       |
# |    explained_variance   | 0.527       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.2        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0118     |
# |    std                  | 0.968       |
# |    value_loss           | 36.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -40.6       |
# | time/                   |             |
# |    fps                  | 667         |
# |    iterations           | 8           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009325285 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.77       |
# |    explained_variance   | 0.758       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.2        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0193     |
# |    std                  | 0.963       |
# |    value_loss           | 39.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -40.6       |
# | time/                   |             |
# |    fps                  | 671         |
# |    iterations           | 9           |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.011289459 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.76       |
# |    explained_variance   | 0.789       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.7        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0165     |
# |    std                  | 0.957       |
# |    value_loss           | 35.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -40.6       |
# | time/                   |             |
# |    fps                  | 674         |
# |    iterations           | 10          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.006977678 |
# |    clip_fraction        | 0.0794      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.74       |
# |    explained_variance   | 0.874       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.8        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0134     |
# |    std                  | 0.951       |
# |    value_loss           | 37.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -40.6        |
# | time/                   |              |
# |    fps                  | 675          |
# |    iterations           | 11           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0099752415 |
# |    clip_fraction        | 0.133        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.73        |
# |    explained_variance   | 0.861        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.1         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.0165      |
# |    std                  | 0.945        |
# |    value_loss           | 39.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -40.6       |
# | time/                   |             |
# |    fps                  | 659         |
# |    iterations           | 12          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.010030455 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.72       |
# |    explained_variance   | 0.891       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.98        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0146     |
# |    std                  | 0.94        |
# |    value_loss           | 29.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -40.6       |
# | time/                   |             |
# |    fps                  | 657         |
# |    iterations           | 13          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008118593 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.7        |
# |    explained_variance   | 0.905       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.4        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0139     |
# |    std                  | 0.932       |
# |    value_loss           | 26.3        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | -40.6      |
# | time/                   |            |
# |    fps                  | 660        |
# |    iterations           | 14         |
# |    time_elapsed         | 43         |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.01248293 |
# |    clip_fraction        | 0.139      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.69      |
# |    explained_variance   | 0.933      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 11.2       |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.0171    |
# |    std                  | 0.927      |
# |    value_loss           | 20.6       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -40.6       |
# | time/                   |             |
# |    fps                  | 663         |
# |    iterations           | 15          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.010893598 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.67       |
# |    explained_variance   | 0.943       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.01        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0129     |
# |    std                  | 0.917       |
# |    value_loss           | 10.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -40.6       |
# | time/                   |             |
# |    fps                  | 655         |
# |    iterations           | 16          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.006785404 |
# |    clip_fraction        | 0.0756      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.63       |
# |    explained_variance   | 0.964       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.29        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0105     |
# |    std                  | 0.897       |
# |    value_loss           | 5.7         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -40.6       |
# | time/                   |             |
# |    fps                  | 646         |
# |    iterations           | 17          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.014413779 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.6        |
# |    explained_variance   | 0.976       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.02        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00913    |
# |    std                  | 0.886       |
# |    value_loss           | 4.44        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -40.6       |
# | time/                   |             |
# |    fps                  | 649         |
# |    iterations           | 18          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.008130377 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.57       |
# |    explained_variance   | 0.977       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.94        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0109     |
# |    std                  | 0.875       |
# |    value_loss           | 3.85        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -40.6       |
# | time/                   |             |
# |    fps                  | 651         |
# |    iterations           | 19          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.010679803 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.54       |
# |    explained_variance   | 0.986       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.26        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00979    |
# |    std                  | 0.862       |
# |    value_loss           | 2.35        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -40.6        |
# | time/                   |              |
# |    fps                  | 643          |
# |    iterations           | 20           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0043104384 |
# |    clip_fraction        | 0.066        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.5         |
# |    explained_variance   | 0.989        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.751        |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00332     |
# |    std                  | 0.842        |
# |    value_loss           | 2.11         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -40.6        |
# | time/                   |              |
# |    fps                  | 642          |
# |    iterations           | 21           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0076154387 |
# |    clip_fraction        | 0.0843       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.47        |
# |    explained_variance   | 0.99         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.44         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00598     |
# |    std                  | 0.836        |
# |    value_loss           | 2.01         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -40.6       |
# | time/                   |             |
# |    fps                  | 644         |
# |    iterations           | 22          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.016804595 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.45       |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.672       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00188    |
# |    std                  | 0.83        |
# |    value_loss           | 1.53        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -40.6       |
# | time/                   |             |
# |    fps                  | 647         |
# |    iterations           | 23          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.004110171 |
# |    clip_fraction        | 0.057       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.43       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.357       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00271    |
# |    std                  | 0.824       |
# |    value_loss           | 1.14        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -40.6        |
# | time/                   |              |
# |    fps                  | 645          |
# |    iterations           | 24           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0040390696 |
# |    clip_fraction        | 0.0916       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.4         |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.798        |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.0015      |
# |    std                  | 0.808        |
# |    value_loss           | 1.06         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -40.6        |
# | time/                   |              |
# |    fps                  | 642          |
# |    iterations           | 25           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0086292885 |
# |    clip_fraction        | 0.0948       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.37        |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.347        |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00428     |
# |    std                  | 0.799        |
# |    value_loss           | 0.891        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -40.6       |
# | time/                   |             |
# |    fps                  | 645         |
# |    iterations           | 26          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.022182804 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.34       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.249       |
# |    n_updates            | 250         |
# |    policy_gradient_loss | 0.000354    |
# |    std                  | 0.791       |
# |    value_loss           | 0.707       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -40.6       |
# | time/                   |             |
# |    fps                  | 647         |
# |    iterations           | 27          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.008902561 |
# |    clip_fraction        | 0.0962      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.31       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.212       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.000998   |
# |    std                  | 0.782       |
# |    value_loss           | 0.653       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -40.6       |
# | time/                   |             |
# |    fps                  | 648         |
# |    iterations           | 28          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.011314029 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.28       |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.232       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00131    |
# |    std                  | 0.769       |
# |    value_loss           | 0.635       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | -40.6      |
# | time/                   |            |
# |    fps                  | 643        |
# |    iterations           | 29         |
# |    time_elapsed         | 92         |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.01167663 |
# |    clip_fraction        | 0.105      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.26      |
# |    explained_variance   | 0.997      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.225      |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.00119   |
# |    std                  | 0.76       |
# |    value_loss           | 0.585      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -40.6       |
# | time/                   |             |
# |    fps                  | 644         |
# |    iterations           | 30          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.009021572 |
# |    clip_fraction        | 0.0824      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.24       |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.381       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.000419   |
# |    std                  | 0.761       |
# |    value_loss           | 0.642       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -40.6       |
# | time/                   |             |
# |    fps                  | 645         |
# |    iterations           | 31          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.012871269 |
# |    clip_fraction        | 0.0917      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.23       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.217       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | 0.000697    |
# |    std                  | 0.75        |
# |    value_loss           | 0.578       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -40.6       |
# | time/                   |             |
# |    fps                  | 647         |
# |    iterations           | 32          |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.008099915 |
# |    clip_fraction        | 0.072       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.2        |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.224       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.000351   |
# |    std                  | 0.742       |
# |    value_loss           | 0.475       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -40.6       |
# | time/                   |             |
# |    fps                  | 644         |
# |    iterations           | 33          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.009214709 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.2        |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.159       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.0027      |
# |    std                  | 0.753       |
# |    value_loss           | 0.436       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -40.6        |
# | time/                   |              |
# |    fps                  | 644          |
# |    iterations           | 34           |
# |    time_elapsed         | 108          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0076111513 |
# |    clip_fraction        | 0.073        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.2         |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.414        |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00214     |
# |    std                  | 0.746        |
# |    value_loss           | 0.566        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -40.6        |
# | time/                   |              |
# |    fps                  | 644          |
# |    iterations           | 35           |
# |    time_elapsed         | 111          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0057248743 |
# |    clip_fraction        | 0.0856       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.19        |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.113        |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00202     |
# |    std                  | 0.744        |
# |    value_loss           | 0.375        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -40.6       |
# | time/                   |             |
# |    fps                  | 646         |
# |    iterations           | 36          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.008057683 |
# |    clip_fraction        | 0.0636      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.17       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0685      |
# |    n_updates            | 350         |
# |    policy_gradient_loss | 0.00131     |
# |    std                  | 0.734       |
# |    value_loss           | 0.353       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -40.6        |
# | time/                   |              |
# |    fps                  | 643          |
# |    iterations           | 37           |
# |    time_elapsed         | 117          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0050364854 |
# |    clip_fraction        | 0.096        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.16        |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.121        |
# |    n_updates            | 360          |
# |    policy_gradient_loss | 0.00285      |
# |    std                  | 0.732        |
# |    value_loss           | 0.362        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -40.6        |
# | time/                   |              |
# |    fps                  | 641          |
# |    iterations           | 38           |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0093111945 |
# |    clip_fraction        | 0.0637       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.16        |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.262        |
# |    n_updates            | 370          |
# |    policy_gradient_loss | 0.000114     |
# |    std                  | 0.732        |
# |    value_loss           | 0.31         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -40.6       |
# | time/                   |             |
# |    fps                  | 642         |
# |    iterations           | 39          |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.006157128 |
# |    clip_fraction        | 0.0824      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.15       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.416       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00495    |
# |    std                  | 0.726       |
# |    value_loss           | 0.317       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -40.6       |
# | time/                   |             |
# |    fps                  | 644         |
# |    iterations           | 40          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.007304213 |
# |    clip_fraction        | 0.0665      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.13       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.245       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00157    |
# |    std                  | 0.718       |
# |    value_loss           | 0.335       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -40.6        |
# | time/                   |              |
# |    fps                  | 643          |
# |    iterations           | 41           |
# |    time_elapsed         | 130          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0040710024 |
# |    clip_fraction        | 0.0998       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.11        |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0693       |
# |    n_updates            | 400          |
# |    policy_gradient_loss | 0.00171      |
# |    std                  | 0.712        |
# |    value_loss           | 0.307        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -40.6        |
# | time/                   |              |
# |    fps                  | 640          |
# |    iterations           | 42           |
# |    time_elapsed         | 134          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0037828742 |
# |    clip_fraction        | 0.101        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.1         |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.083        |
# |    n_updates            | 410          |
# |    policy_gradient_loss | 0.00283      |
# |    std                  | 0.712        |
# |    value_loss           | 0.306        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -40.6        |
# | time/                   |              |
# |    fps                  | 641          |
# |    iterations           | 43           |
# |    time_elapsed         | 137          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0036817063 |
# |    clip_fraction        | 0.0616       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.1         |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0881       |
# |    n_updates            | 420          |
# |    policy_gradient_loss | 0.00126      |
# |    std                  | 0.715        |
# |    value_loss           | 0.291        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -40.6       |
# | time/                   |             |
# |    fps                  | 642         |
# |    iterations           | 44          |
# |    time_elapsed         | 140         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.005255549 |
# |    clip_fraction        | 0.0775      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.1        |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0761      |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00257    |
# |    std                  | 0.717       |
# |    value_loss           | 0.313       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -40.6       |
# | time/                   |             |
# |    fps                  | 643         |
# |    iterations           | 45          |
# |    time_elapsed         | 143         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.005376125 |
# |    clip_fraction        | 0.0528      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.1        |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.131       |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.000285   |
# |    std                  | 0.713       |
# |    value_loss           | 0.298       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -40.6       |
# | time/                   |             |
# |    fps                  | 639         |
# |    iterations           | 46          |
# |    time_elapsed         | 147         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.004420217 |
# |    clip_fraction        | 0.0667      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.1        |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.104       |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.00136     |
# |    std                  | 0.719       |
# |    value_loss           | 0.257       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -40.6       |
# | time/                   |             |
# |    fps                  | 640         |
# |    iterations           | 47          |
# |    time_elapsed         | 150         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.005535648 |
# |    clip_fraction        | 0.0581      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.11       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.145       |
# |    n_updates            | 460         |
# |    policy_gradient_loss | 0.00103     |
# |    std                  | 0.719       |
# |    value_loss           | 0.28        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -40.6       |
# | time/                   |             |
# |    fps                  | 642         |
# |    iterations           | 48          |
# |    time_elapsed         | 153         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.003826037 |
# |    clip_fraction        | 0.087       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.12       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0758      |
# |    n_updates            | 470         |
# |    policy_gradient_loss | 0.00339     |
# |    std                  | 0.723       |
# |    value_loss           | 0.238       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -40.6        |
# | time/                   |              |
# |    fps                  | 643          |
# |    iterations           | 49           |
# |    time_elapsed         | 155          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0130478125 |
# |    clip_fraction        | 0.0833       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.11        |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.102        |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00135     |
# |    std                  | 0.719        |
# |    value_loss           | 0.241        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -40.6       |
# | time/                   |             |
# |    fps                  | 641         |
# |    iterations           | 50          |
# |    time_elapsed         | 159         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.007359975 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.1        |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.122       |
# |    n_updates            | 490         |
# |    policy_gradient_loss | 0.00407     |
# |    std                  | 0.721       |
# |    value_loss           | 0.252       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -40.6       |
# | time/                   |             |
# |    fps                  | 641         |
# |    iterations           | 51          |
# |    time_elapsed         | 162         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.024534218 |
# |    clip_fraction        | 0.0564      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.11       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0614      |
# |    n_updates            | 500         |
# |    policy_gradient_loss | 0.00231     |
# |    std                  | 0.721       |
# |    value_loss           | 0.306       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -40.6       |
# | time/                   |             |
# |    fps                  | 642         |
# |    iterations           | 52          |
# |    time_elapsed         | 165         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.010653015 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.11       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0803      |
# |    n_updates            | 510         |
# |    policy_gradient_loss | 5.44e-05    |
# |    std                  | 0.722       |
# |    value_loss           | 0.247       |
# -----------------------------------------
# ...
# |    loss                 | 0.0886      |
# |    n_updates            | 800         |
# |    policy_gradient_loss | 0.00106     |
# |    std                  | 0.65        |
# |    value_loss           | 0.183       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -40.6        |
# | time/                   |              |
# |    fps                  | 637          |
# |    iterations           | 82           |
# |    time_elapsed         | 263          |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0056544645 |
# |    clip_fraction        | 0.119        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.9         |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0391       |
# |    n_updates            | 810          |
# |    policy_gradient_loss | 0.00153      |
# |    std                  | 0.655        |
# |    value_loss           | 0.206        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -40.6       |
# | time/                   |             |
# |    fps                  | 637         |
# |    iterations           | 83          |
# |    time_elapsed         | 266         |
# |    total_timesteps      | 169984      |
# | train/                  |             |
# |    approx_kl            | 0.012511246 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.91       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0524      |
# |    n_updates            | 820         |
# |    policy_gradient_loss | -0.001      |
# |    std                  | 0.656       |
# |    value_loss           | 0.2         |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 50        |
# |    ep_rew_mean          | -40.6     |
# | time/                   |           |
# |    fps                  | 635       |
# |    iterations           | 84        |
# |    time_elapsed         | 270       |
# |    total_timesteps      | 172032    |
# | train/                  |           |
# |    approx_kl            | 0.0057571 |
# |    clip_fraction        | 0.104     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.91     |
# |    explained_variance   | 0.999     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.141     |
# |    n_updates            | 830       |
# |    policy_gradient_loss | -0.000164 |
# |    std                  | 0.659     |
# |    value_loss           | 0.173     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | -40.6      |
# | time/                   |            |
# |    fps                  | 635        |
# |    iterations           | 85         |
# |    time_elapsed         | 273        |
# |    total_timesteps      | 174080     |
# | train/                  |            |
# |    approx_kl            | 0.02023995 |
# |    clip_fraction        | 0.0718     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.91      |
# |    explained_variance   | 0.999      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0558     |
# |    n_updates            | 840        |
# |    policy_gradient_loss | -0.00238   |
# |    std                  | 0.651      |
# |    value_loss           | 0.179      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | -40.6      |
# | time/                   |            |
# |    fps                  | 636        |
# |    iterations           | 86         |
# |    time_elapsed         | 276        |
# |    total_timesteps      | 176128     |
# | train/                  |            |
# |    approx_kl            | 0.00661185 |
# |    clip_fraction        | 0.105      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.89      |
# |    explained_variance   | 1          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0911     |
# |    n_updates            | 850        |
# |    policy_gradient_loss | 0.00309    |
# |    std                  | 0.647      |
# |    value_loss           | 0.17       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -40.6        |
# | time/                   |              |
# |    fps                  | 636          |
# |    iterations           | 87           |
# |    time_elapsed         | 279          |
# |    total_timesteps      | 178176       |
# | train/                  |              |
# |    approx_kl            | 0.0046683783 |
# |    clip_fraction        | 0.101        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.88        |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0736       |
# |    n_updates            | 860          |
# |    policy_gradient_loss | -0.00186     |
# |    std                  | 0.644        |
# |    value_loss           | 0.173        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -40.6        |
# | time/                   |              |
# |    fps                  | 635          |
# |    iterations           | 88           |
# |    time_elapsed         | 283          |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0076773567 |
# |    clip_fraction        | 0.144        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.88        |
# |    explained_variance   | 1            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0495       |
# |    n_updates            | 870          |
# |    policy_gradient_loss | -0.00267     |
# |    std                  | 0.646        |
# |    value_loss           | 0.164        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -40.6       |
# | time/                   |             |
# |    fps                  | 634         |
# |    iterations           | 89          |
# |    time_elapsed         | 287         |
# |    total_timesteps      | 182272      |
# | train/                  |             |
# |    approx_kl            | 0.003865802 |
# |    clip_fraction        | 0.0958      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.87       |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.172       |
# |    n_updates            | 880         |
# |    policy_gradient_loss | 0.000258    |
# |    std                  | 0.637       |
# |    value_loss           | 0.16        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -40.6       |
# | time/                   |             |
# |    fps                  | 635         |
# |    iterations           | 90          |
# |    time_elapsed         | 290         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.003824137 |
# |    clip_fraction        | 0.072       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.85       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.145       |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.00144    |
# |    std                  | 0.637       |
# |    value_loss           | 0.133       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -40.6       |
# | time/                   |             |
# |    fps                  | 635         |
# |    iterations           | 91          |
# |    time_elapsed         | 293         |
# |    total_timesteps      | 186368      |
# | train/                  |             |
# |    approx_kl            | 0.006562225 |
# |    clip_fraction        | 0.0863      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.84       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0649      |
# |    n_updates            | 900         |
# |    policy_gradient_loss | 0.00112     |
# |    std                  | 0.631       |
# |    value_loss           | 0.161       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -40.6       |
# | time/                   |             |
# |    fps                  | 635         |
# |    iterations           | 92          |
# |    time_elapsed         | 296         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.008618716 |
# |    clip_fraction        | 0.0979      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.83       |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0482      |
# |    n_updates            | 910         |
# |    policy_gradient_loss | -0.000641   |
# |    std                  | 0.637       |
# |    value_loss           | 0.146       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -40.6       |
# | time/                   |             |
# |    fps                  | 634         |
# |    iterations           | 93          |
# |    time_elapsed         | 300         |
# |    total_timesteps      | 190464      |
# | train/                  |             |
# |    approx_kl            | 0.008418881 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.83       |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.11        |
# |    n_updates            | 920         |
# |    policy_gradient_loss | 0.00273     |
# |    std                  | 0.633       |
# |    value_loss           | 0.169       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -40.6        |
# | time/                   |              |
# |    fps                  | 634          |
# |    iterations           | 94           |
# |    time_elapsed         | 303          |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0032317021 |
# |    clip_fraction        | 0.0812       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.82        |
# |    explained_variance   | 1            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0395       |
# |    n_updates            | 930          |
# |    policy_gradient_loss | 0.00132      |
# |    std                  | 0.627        |
# |    value_loss           | 0.157        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -40.6       |
# | time/                   |             |
# |    fps                  | 635         |
# |    iterations           | 95          |
# |    time_elapsed         | 306         |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.010657124 |
# |    clip_fraction        | 0.0815      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.8        |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0242      |
# |    n_updates            | 940         |
# |    policy_gradient_loss | 0.00213     |
# |    std                  | 0.623       |
# |    value_loss           | 0.155       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -40.6       |
# | time/                   |             |
# |    fps                  | 635         |
# |    iterations           | 96          |
# |    time_elapsed         | 309         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.010619235 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.78       |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0454      |
# |    n_updates            | 950         |
# |    policy_gradient_loss | 0.00389     |
# |    std                  | 0.617       |
# |    value_loss           | 0.156       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -40.6       |
# | time/                   |             |
# |    fps                  | 633         |
# |    iterations           | 97          |
# |    time_elapsed         | 313         |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.010696629 |
# |    clip_fraction        | 0.0493      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.78       |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.111       |
# |    n_updates            | 960         |
# |    policy_gradient_loss | 0.000397    |
# |    std                  | 0.615       |
# |    value_loss           | 0.171       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -40.6        |
# | time/                   |              |
# |    fps                  | 634          |
# |    iterations           | 98           |
# |    time_elapsed         | 316          |
# |    total_timesteps      | 200704       |
# | train/                  |              |
# |    approx_kl            | 0.0053489115 |
# |    clip_fraction        | 0.0671       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.77        |
# |    explained_variance   | 1            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0646       |
# |    n_updates            | 970          |
# |    policy_gradient_loss | -0.00247     |
# |    std                  | 0.611        |
# |    value_loss           | 0.142        |
# ------------------------------------------

# %%
log_path = os.path.join(drive_log_dir, "monitor.csv")
df = pd.read_csv(log_path, skiprows=1)
# Ensure episodes are logged correctly
df.reset_index(inplace=True)
df.rename(columns={"index": "episode", "r": "reward", "l": "length", "t": "time_step"}, inplace=True)

# %%
data_table.enable_dataframe_formatter()
data_table.DataTable(df.head())
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>episode</th>
#       <th>reward</th>
#       <th>length</th>
#       <th>time_step</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>-40.62468</td>
#       <td>50</td>
#       <td>8.671672</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>-40.62468</td>
#       <td>50</td>
#       <td>8.729833</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>-40.62468</td>
#       <td>50</td>
#       <td>8.768548</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>-40.62468</td>
#       <td>50</td>
#       <td>8.808472</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>-40.62468</td>
#       <td>50</td>
#       <td>8.847515</td>
#     </tr>
#   </tbody>
# </table>
# </div>
